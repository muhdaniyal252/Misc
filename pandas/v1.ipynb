# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
pd.set_option('display.max_rows',85)
pd.set_option('display.max_columns',85)

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[0,'Hobbyist']
# Out:
# 'Yes'

# %%
df.loc[[0,1,2],'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0:2,'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0:2, 'Hobbyist':'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %%
df.index
# Out:
# RangeIndex(start=0, stop=88883, step=1)

# %%
df = pd.read_csv('data/survey_results_public.csv',index_col='Respondent')

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv',index_col='Column')

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc['MgrIdiot']
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
schema_df.loc['MgrIdiot','QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index(ascending=False,inplace=True)

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %%
#need to find salary 
high_salary = (df['ConvertedComp'] > 70000)

# %%
df.loc[high_salary]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5               6  I am not primarily a developer, but I write co...      Yes
# 8               9                     I am a developer by profession      Yes
# 12             13                     I am a developer by profession      Yes
# 15             16                     I am a developer by profession      Yes
# 21             22                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88323       88876                     I am a developer by profession      Yes
# 88324       88877                     I am a developer by profession      Yes
# 88325       88878                     I am a developer by profession      Yes
# 88326       88879                     I am a developer by profession      Yes
# 88329       88882                     I am a developer by profession      Yes
#
# ...

# %%
df.loc[high_salary,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#               Country                                 LanguageWorkedWith  \
# 5              Canada                                         Java;R;SQL
# 8         New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12      United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15     United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 21      United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...               ...                                                ...
# 88323   United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88324   United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88325   United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88326         Finland                   Bash/Shell/PowerShell;C++;Python
# 88329     Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
#        ConvertedComp
# 5           366420.0
# 8            95179.0
# 12           90000.0
# ...

# %%
cont_list = ['India','United States','United Kingdom','Germany','Canada']

# %%
filt = df['Country'].isin(cont_list)

# %%
df.loc[filt,'Country']
# Out:
# 0        United Kingdom
# 3         United States
# 5                Canada
# 7                 India
# 9                 India
#               ...
# 88859     United States
# 88863    United Kingdom
# 88864             India
# 88877     United States
# 88878            Canada
# Name: Country, Length: 45008, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 2                                                 HTML/CSS
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88878                        HTML/CSS;JavaScript;Other(s):
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python')

# %%
# df.loc[filt]

# %%
filt = df['LanguageWorkedWith'].str.contains('Python',na=False)

# %%
df.loc[filt,'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'})
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'},inplace=True)

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].map({'Yes': True, 'No':False})
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 88878     True
# 88879    False
# 88880    False
# 88881    False
# 88882     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No':False})

# %%
df['Hobbyist']
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 88878     True
# 88879    False
# 88880    False
# 88881    False
# 88882     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist'].map(lambda x: 0 )
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 88878    0
# 88879    0
# 88880    0
# 88881    0
# 88882    0
# Name: Hobbyist, Length: 88883, dtype: int64

# %%
df['Hobbyist'].map(lambda x: 1 if x else 0), df['Hobbyist']
# Out:
# (0        1
#  1        0
#  2        1
#  3        0
#  4        1
#          ..
#  88878    1
#  88879    0
#  88880    0
#  88881    0
#  88882    1
#  Name: Hobbyist, Length: 88883, dtype: int64,
#  0         True
#  1        False
#  2         True
#  3        False
#  4         True
#           ...
#  88878     True
#  88879    False
#  88880    False
#  88881    False
#  88882     True
#  Name: Hobbyist, Length: 88883, dtype: bool)

# %%
df.sort_values(by='Country',inplace=True)

# %%
df['Country'].head(50)
# Out:
# 39018    Afghanistan
# 62723    Afghanistan
# 85185    Afghanistan
# 50437    Afghanistan
# 88340    Afghanistan
# 88735    Afghanistan
# 6391     Afghanistan
# 39754    Afghanistan
# 88181    Afghanistan
# 48122    Afghanistan
# 10697    Afghanistan
# 62124    Afghanistan
# 49377    Afghanistan
# 32971    Afghanistan
# 60559    Afghanistan
# 85827    Afghanistan
# 88033    Afghanistan
# 28470    Afghanistan
# 719      Afghanistan
# 26189    Afghanistan
# 86394    Afghanistan
# 85293    Afghanistan
# 7056     Afghanistan
# 7323     Afghanistan
# 86551    Afghanistan
# 58390    Afghanistan
# 73920    Afghanistan
# 28877    Afghanistan
# 51525    Afghanistan
# 45562    Afghanistan
# 46807    Afghanistan
# 44123    Afghanistan
# 22327    Afghanistan
# 8112     Afghanistan
# 80423    Afghanistan
# 59184    Afghanistan
# 60185    Afghanistan
# 37571    Afghanistan
# 29560    Afghanistan
# 42832    Afghanistan
# 12253    Afghanistan
# 58082    Afghanistan
# 61770    Afghanistan
# ...

# %%
df[['Country','SalaryUSD']].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10800\1312221662.py in <module>
# ----> 1 df[['Country','SalaryUSD']].head()
#
# d:\envs\ds\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# d:\envs\ds\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
df.sort_values(by=['Country','SalaryUSD'], ascending=[True,False])[['Country','SalaryUSD']].head(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10800\313043752.py in <module>
# ----> 1 df.sort_values(by=['Country','SalaryUSD'], ascending=[True,False])[['Country','SalaryUSD']].head(50)
#
# d:\envs\ds\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# d:\envs\ds\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6240         if len(by) > 1:
#    6241
# -> 6242             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6243
#    6244             # need to rewrap columns in Series to apply key function
#
# ...

# %%
filt = (df['Country'] == 'Pakistan')

# %%
df.loc[filt]
# Out:
#        Respondent                                         MainBranch  \
# 39217       39461             I am a student who is learning to code
# 70633       71083                     I am a developer by profession
# 25063       25210                     I am a developer by profession
# 70478       70925                     I am a developer by profession
# 47776       48087                     I am a developer by profession
# ...           ...                                                ...
# 79702       80201                     I am a developer by profession
# 66157       66578             I am a student who is learning to code
# 20719       20834  I am not primarily a developer, but I write co...
# 7237         7267                     I am a developer by profession
# 88567       39117                                                NaN
#
#        Hobbyist                                        OpenSourcer  \
# 39217      True                                              Never
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\envs\ds\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# d:\envs\ds\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# d:\envs\ds\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalaryUSD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.nlargest(10,'SalaryUSD')['Country']
# Out:
# Respondent
# 25983         Canada
# 87896        Germany
# 22013          India
# 28243          India
# 72732          India
# 78151         Mexico
# 80200    Netherlands
# 52132           Peru
# 75561      Singapore
# 32250    Switzerland
# Name: Country, dtype: object

# %%
df.nsmallest(10,'SalaryUSD')['Country']
# Out:
# Respondent
# 28638               Afghanistan
# 722                 Afghanistan
# 13825                   Algeria
# 40913                   Armenia
# 30630                 Australia
# 69049                 Australia
# 19340                   Austria
# 16214                Bangladesh
# 29355    Bosnia and Herzegovina
# 1685                     Brazil
# Name: Country, dtype: object

# %%
df.loc[df['Country'].str.contains('United',na=False)]['Country'].value_counts()
# Out:
# United States                  20949
# United Kingdom                  5737
# United Arab Emirates             158
# United Republic of Tanzania       32
# Name: Country, dtype: int64

# %%
df['SalaryUSD'].head(15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\envs\ds\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# d:\envs\ds\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# d:\envs\ds\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalaryUSD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df['ConvertedComp'].mean()
# Out:
# 127110.73842323056

# %%
df.median()
# Out:
# d:\envs\ds\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Respondent       44442.0
# Hobbyist             1.0
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Respondent       44442.0
# Hobbyist             1.0
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df['ConvertedComp'].describe()
# Out:
# count    5.582300e+04
# mean     1.271107e+05
# std      2.841523e+05
# min      0.000000e+00
# 25%      2.577750e+04
# 50%      5.728700e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88883 entries, 39018 to 88881
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  bool
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
df['Hobbyist']
# Out:
# 39018     True
# 62723     True
# 85185    False
# 50437    False
# 88340     True
#          ...
# 88873    False
# 88874    False
# 88879    False
# 88880    False
# 88881    False
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist'].value_counts()
# Out:
# True     71257
# False    17626
# Name: Hobbyist, dtype: int64

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
schema_df.set_index(schema_df.columns[0],inplace=True)

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: Country, Length: 179, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#        Respondent                                         MainBranch  \
# 32185       32379                     I am a developer by profession
# 81237       81742                     I am a developer by profession
# 74830       75299                     I am a developer by profession
# 66479       66901                     I am a developer by profession
# 22889       23018                     I am a developer by profession
# ...           ...                                                ...
# 79134       79628                     I am a developer by profession
# 88577       40151                                                NaN
# 75925       76400  I am not primarily a developer, but I write co...
# 30745       30928                     I am a developer by profession
# 30271       30452             I am a student who is learning to code
#
#        Hobbyist                                        OpenSourcer  \
# 32185     False                                              Never
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# WeChat 微信                      5
# Hello                          5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
filt = df['Country'] == 'Pakistan'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# WhatsApp                    266
# Facebook                    232
# YouTube                     182
# LinkedIn                     71
# Twitter                      58
# Instagram                    41
# Reddit                       28
# I don't use social media     23
# Snapchat                      5
# VK ВКонта́кте                 1
# Hello                         1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: SocialMedia, Length: 1220, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['Russian Federation']
# Out:
# SocialMedia
# VK ВКонта́кте               442
# YouTube                     302
# I don't use social media    155
# Reddit                      140
# Twitter                     130
# Instagram                    94
# WhatsApp                     90
# Facebook                     67
# LinkedIn                     35
# Snapchat                      1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=0).loc['Russian Federation']
# Out:
# SocialMedia
# VK ВКонта́кте               442
# YouTube                     302
# I don't use social media    155
# Reddit                      140
# Twitter                     130
# Instagram                    94
# WhatsApp                     90
# Facebook                     67
# LinkedIn                     35
# Snapchat                      1
# Name: SocialMedia, dtype: int64

# %%
country_grp['ConvertedComp'].mean()
# Out:
# Country
# Afghanistan                             101953.333333
# Albania                                  21833.700000
# Algeria                                  34924.047619
# Andorra                                 160931.000000
# Angola                                    7764.000000
#                                             ...
# Venezuela, Bolivarian Republic of...     14581.627907
# Viet Nam                                 17233.436782
# Yemen                                    16909.166667
# Zambia                                   10075.375000
# Zimbabwe                                 34046.666667
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
country_grp['ConvertedComp'].median()['Palistan']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\envs\ds\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# d:\envs\ds\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# d:\envs\ds\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Palistan'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
country_grp['ConvertedComp'].mean().loc['Pakistan']
# Out:
# 12115.1990521327

# %%
country_grp['ConvertedComp'].agg(['mean','mean','std'])
# Out:
#                                                mean           mean  \
# Country
# Afghanistan                           101953.333333  101953.333333
# Albania                                21833.700000   21833.700000
# Algeria                                34924.047619   34924.047619
# Andorra                               160931.000000  160931.000000
# Angola                                  7764.000000    7764.000000
# ...                                             ...            ...
# Venezuela, Bolivarian Republic of...   14581.627907   14581.627907
# Viet Nam                               17233.436782   17233.436782
# Yemen                                  16909.166667   16909.166667
# Zambia                                 10075.375000   10075.375000
# Zimbabwe                               34046.666667   34046.666667
#
#                                                 std
# Country
# Afghanistan                           285995.241798
# ...

# %%
country_grp['ConvertedComp'].agg(['mean','mean','std']).loc['Pakistan']
# Out:
# mean    12115.199052
# mean    12115.199052
# std     47247.794314
# Name: Pakistan, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10800\2028201116.py in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# d:\envs\ds\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     910
#     911         raise AttributeError(
# --> 912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#     914
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: (x.str.contains('Python').sum())/len(x))
# Out:
# Country
# Afghanistan                             0.181818
# Albania                                 0.267442
# Algeria                                 0.298507
# Andorra                                 0.000000
# Angola                                  0.400000
#                                           ...
# Venezuela, Bolivarian Republic of...    0.318182
# Viet Nam                                0.337662
# Yemen                                   0.157895
# Zambia                                  0.333333
# Zimbabwe                                0.358974
# Name: LanguageWorkedWith, Length: 179, dtype: float64

# %%
country_respondents = df['Country'].value_counts()

# %%
country_respondents
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents,country_uses_python]
        ,axis='columns'
        ,sort=False
        )
python_df
# Out:
#                                   Country  LanguageWorkedWith
# United States                       20949               10083
# India                                9061                3105
# Germany                              5866                2451
# United Kingdom                       5737                2384
# Canada                               3395                1558
# ...                                   ...                 ...
# North Korea                             1                   0
# Niger                                   1                   1
# Saint Vincent and the Grenadines        1                   0
# Chad                                    1                   0
# Brunei Darussalam                       1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'LanguageWorkedWith':'NumKnowsPython','Country':'NumRespondents'},inplace=True)

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100

# %%
python_df
# Out:
#                                   NumRespondents  NumKnowsPython  \
# United States                              20949           10083
# India                                       9061            3105
# Germany                                     5866            2451
# United Kingdom                              5737            2384
# Canada                                      3395            1558
# ...                                          ...             ...
# North Korea                                    1               0
# Niger                                          1               1
# Saint Vincent and the Grenadines               1               0
# Chad                                           1               0
# Brunei Darussalam                              1               0
#
#                                   PctKnowsPython
# United States                          48.131176
# India                                  34.267741
# ...

# %%
python_df.sort_values(by='PctKnowsPython',ascending=False,inplace=True)

# %%
python_df
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Sao Tome and Principe                          1               1
# Niger                                          1               1
# Dominica                                       1               1
# Timor-Leste                                    1               1
# Turkmenistan                                   7               6
# ...                                          ...             ...
# Burkina Faso                                   4               0
# Lao People's Democratic Republic               3               0
# Gabon                                          2               0
# Cape Verde                                     3               0
# Brunei Darussalam                              1               0
#
#                                   PctKnowsPython
# Sao Tome and Principe                 100.000000
# Niger                                 100.000000
# ...

# %%
python_df.sort_values(by=['NumRespondents','PctKnowsPython'],ascending=False)
# Out:
#                                   NumRespondents  NumKnowsPython  \
# United States                              20949           10083
# India                                       9061            3105
# Germany                                     5866            2451
# United Kingdom                              5737            2384
# Canada                                      3395            1558
# ...                                          ...             ...
# Saint Vincent and the Grenadines               1               0
# North Korea                                    1               0
# Tonga                                          1               0
# Papua New Guinea                               1               0
# Brunei Darussalam                              1               0
#
#                                   PctKnowsPython
# United States                          48.131176
# India                                  34.267741
# ...

# %%
na_values = ['NA','Missing']
df = pd.read_csv('data/survey_results_public.csv',index_col='Respondent',na_values=na_values)

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1       4
# 2     NaN
# 3       3
# 4       3
# 5      16
# 6      13
# 7       6
# 8       8
# 9      12
# 10     12
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10800\2991359917.py in <module>
# ----> 1 df['YearsCode'].mean()
#
# d:\envs\ds\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# d:\envs\ds\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
#   10369         return self._stat_function(
# > 10370             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
# ...

# %%
df['YearsCode'].info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10800\3576928090.py in <module>
# ----> 1 df['YearsCode'].info()
#
# d:\envs\ds\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10800\461662191.py in <module>
# ----> 1 df['YearsCode'].astype(float)
#
# d:\envs\ds\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# d:\envs\ds\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace=True)

# %%
df['YearsCode'].replace('More than 50 years',51,inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', 51, '29',
#        '44', '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0
